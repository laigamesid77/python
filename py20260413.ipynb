# %% [markdown]
# <a href="https://colab.research.google.com/github/laigamesid77/python/blob/main/py20260413.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import urllib.request as req
import pandas as pd

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=47221&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
content = json.loads(content)
danmu = content["data"]["danmu"]
df = pd.DataFrame(danmu)
df.to_csv("danmu.csv", encoding="utf-8")
df
# Out:
#                     text    color  size  position   time        sn  \
# 0                   讚阿XD  #FFFFFF     1         0      0  47806325
# 1            悲報，距離完結還有9集  #FDE53D     1         0      0  47808838
# 2                  巴哈我大哥  #FFFFFF     1         0      0  47812257
# 3                 簽 hiro  #0036FA     1         2      0  47840473
# 4          2026/01/22 簽~  #00C3FC     1         0      0  47866460
# ...                  ...      ...   ...       ...    ...       ...
# 2996      現實是會沖倒暗河而沿水脈而歸  #FFFFFF     1         0  14400  47828222
# 2997              超級帥的大叔  #FFFFFF     1         0  14400  47835270
# 2998         2026.1.21 *  #FFFFFF     1         0  14400  47856058
# 2999  天啊！！！下一集就是南之勇者啦！！！  #FFFFFF     1         0  14400  47858790
# 3000            天啊  片尾好美  #FFFFFF     1         0  14400  48334763
#
#            userid
# 0       j11161984
# 1        BENNY319
# 2        milk2009
# 3        andyhiro
# 4       joe871114
# ...           ...
# 2996    z999999op
# 2997  Jacschnapps
# 2998      s935602
# 2999  khst9021735
# 3000    kou050198
#
# [3001 rows x 7 columns]

# %%
import pandas as pd
import os
# 要有資料夾才能存檔,須先創建
dn = "baha2"
#如果資料夾不存在 就開起來
if not os.path.exists(dn):
    os.makedirs(dn)
# 加這個索引不會變成多一欄 index_col=0
df = pd.read_csv("danmu.csv", encoding="utf-8", index_col=0)

for u in df["userid"].unique():
    fil = df["userid"] == u
    fn = dn + "/" + u + ".csv"
    df[fil].to_csv(fn, encoding="utf-8")

# %%
import urllib.request as req

url = "https://github.com/Elwing-Chou/ximen20260316/raw/refs/heads/main/chiikawa.html"
h = {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36"
}
r = req.Request(url,headers=h)
f = req.urlopen(r)
content = f.read()
print(content)
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="zh-Hant-TW" data-theme="light" data-geo="TW">\r\n<head>\r\n<title>\xe5\x90\x89\xe4\xbc\x8a\xe5\x8d\xa1\xe5\x93\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b - \xe5\xb7\xb4\xe5\x93\x88\xe5\xa7\x86\xe7\x89\xb9\xe5\x8b\x95\xe7\x95\xab\xe7\x98\x8b</title>\r\n<meta http-equiv="Content-Type" content="text/html" charset="utf-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\r\n<meta name="description" content="\xe5\x90\x89\xe4\xbc\x8a\xe5\x8d\xa1\xe5\x93\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b! 2022">\r\n<meta name="thumbnail" content="https://p2.bahamut.com.tw/B/2KU/38/ac36cd567b30717d7a44d59e371odhi5.JPG">\r\n<meta property="og:title" content="\xe5\x90\x89\xe4\xbc\x8a\xe5\x8d\xa1\xe5\x93\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b">\r\n<meta property="og:type" content="website">\r\n<meta property="og:url" content="https://ani.gamer.com.tw/animeVideo.php?sn=36632">\r\n<meta property="og:image" content="https://p2.bahamut.com.tw/B/2KU/38/ac36cd567b30717d7a44d59e371odhi5.JPG">\r\n<meta property="og:description" content="\xe5\x90\x89\xe4\xbc\x8a\xe5\x8d\xa1\xe5\x93\x87 [1] \xe7\xb7\x9a\xe4\xb8\x8a\xe7\x9c\x8b! 2022\x ...
