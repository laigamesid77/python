# %% [markdown]
# <a href="https://colab.research.google.com/github/laigamesid77/python/blob/main/py20260401.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#開啟cmd(命令提示字元)輸入
#第一個參數 -headers "Origin: https://ani.gamer.com.tw"
#第二個參數 -1 是input "網址Request URL:"(chunklist_b1200000.m3u8[這是影片清單])
#第三個參數 檔名+要轉換的格式(例: music.mp3)
-headers "Origin: https://ani.gamer.com.tw" -i "https://bahamut.akamaized.net/0500075bff9d0e2d9bfaf7afbf5d08b0433aab69/360p/hdntl=exp=1775129340~acl=%2f0500075bff9d0e2d9bfaf7afbf5d08b0433aab69%2fplaylist_guest.m3u8!%2f0500075bff9d0e2d9bfaf7afbf5d08b0433aab69%2f360p%2f*~data=hdntl,c6c1c487ca8c16c%3a5575%3a0%3a1%3a53535324%3a0~hmac=7d2290c5a9da2011341757ed4b65532b8b33b681873668c219333ba2621f2e99/chunklist_b400000.m3u8" anime.mp4

# %%
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=5575&geo=TW%2CHK&limit=50"

f = req.urlopen(url)
content = f.read()
print(content)
# Out:
# b'{"data":{"danmu":[{"text":"\\u597d\\u6162\\u554a \\u3002\\u3002\\u3002","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":3747112,"userid":"abc23612093"},{"text":"\\u8981\\u4e0b\\u67b6\\u4e86 \\u4e0d\\u8981\\u311a\\u311a\\u311a \\uff1b\\uff1b\\uff1b\\uff1b 2018.09.29","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":7149639,"userid":"ws7955231"},{"text":"OMG\\u597d\\u6211\\u518d\\u770b\\u4e00\\u6b21!!!","color":"#FF9625","size":1,"position":0,"time":0,"sn":13874507,"userid":"a42469226"},{"text":"2020.8.14\\u5eab\\u62c9\\u76ae\\u5361\\u9084\\u6c92\\u4e0b\\u8239\\u3002\\u4f11\\u520a81\\u671f\\u7d00\\u9304\\u3002","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":15493610,"userid":"weichenhuang"},{"text":"\\u597d\\u770b","color":"#B538FA","size":1,"position":0,"time":0,"sn":24682238,"userid":"Yuzz0830"},{"text":"2022\\/2\\/3\\u516d\\u5237OuO","color":"#FFFFFF","size":1,"position":0,"time":0,"sn":25150907,"userid":"Yunyou1122"},{"text":"2022 30\\u591a\\u5237","color":"#FF9
# ...

# %%
f = open("a.txt", "w", encoding="utf-8")
f.write("text1\n")
f.write("zzz")
f.close()

# %%
f = open("a.txt", "r", encoding="utf-8")
content = f.read()
print(content)
f.close()
# Out:
# text1
# zzz
